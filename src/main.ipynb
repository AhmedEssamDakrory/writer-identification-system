# %%
from main import*

# %%
main_2()
# Out:
# Test:  1
# trainging.........writer: 212
# trainging.........writer: 458
# trainging.........writer: 588
# predicting...........
# line 0 presidctions is:
# ['458']
# line 1 presidctions is:
# ['458']
# line 2 presidctions is:
# ['458']
# line 3 presidctions is:
# ['458']
# line 4 presidctions is:
# ['458']
# line 5 presidctions is:
# ['458']
# line 6 presidctions is:
# ['458']
# Prediction: 458
# Time taken: 6.24
# Test:  2
# trainging.........writer: 248
# trainging.........writer: 495
# trainging.........writer: 584
# predicting...........
# line 0 presidctions is:
# ['248']
# line 1 presidctions is:
# ['248']
# line 2 presidctions is:
# ['248']
# line 3 presidctions is:
# ['248']
# line 4 presidctions is:
# ['248']
# Wrong classified at TestCase  2
# Prediction: 248
# Time taken: 5.89
# Test:  3
# trainging.........writer: 110
# trainging.........writer: 333
# trainging.........writer: 546
# predicting...........
# line 0 presidctions is:
# ['333']
# line 1 presidctions is:
# ...
